# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('./vars.txt', sep='\s+', low_memory=False)
df = df.replace('x', 0).astype(int)

df_q = pd.read_csv('./q_fit_10bits_no_drop.txt', header=None)
df_q[1] = np.arange(0, 1023)
df_q.columns = ['q_measured', 'i_ref']

df_q = df_q.iloc[: , [1, 0]]

df_q
# Out:
#       i_ref  q_measured
# 0         0          22
# 1         1          22
# 2         2          22
# 3         3          22
# 4         4          22
# ...     ...         ...
# 1018   1018         300
# 1019   1019         303
# 1020   1020         307
# 1021   1021         310
# 1022   1022         314
#
# [1023 rows x 2 columns]

# %%
df_r = df[df['ready'] == 1]

# %%
df_r
# Out:
#           time  clk  rst  start  enable  i_ref  q_measured  ready  q_desired  \
# 697        697    1    0      1       1    511          56      1         26
# 698        698    0    0      1       1    511          56      1         26
# 1131      1131    1    0      1       1    255          35      1         26
# 1132      1132    0    0      1       1    255          35      1         26
# 1493      1493    1    0      1       1    127          29      1         26
# ...        ...  ...  ...    ...     ...    ...         ...    ...        ...
# 148966  148966    0    0      1       1   1015         290      1        314
# 152615  152615    1    0      1       1   1019         303      1        314
# 152616  152616    0    0      1       1   1019         303      1        314
# 156349  156349    1    0      1       1   1021         310      1        314
# 156350  156350    0    0      1       1   1021         310      1        314
#
#         converged
# 697             0
# 698             0
# 1131            0
# 1132            0
# 1493            0
# ...           ...
# 148966          0
# 152615          0
# 152616          0
# 156349          0
# 156350          0
#
# [184 rows x 10 columns]

# %%
df_r
# Out:
#           time  clk  rst  start  enable  i_ref  q_measured  ready  q_desired  \
# 697        697    1    0      1       1    511          56      1         26
# 698        698    0    0      1       1    511          56      1         26
# 1131      1131    1    0      1       1    255          35      1         26
# 1132      1132    0    0      1       1    255          35      1         26
# 1493      1493    1    0      1       1    127          29      1         26
# ...        ...  ...  ...    ...     ...    ...         ...    ...        ...
# 148966  148966    0    0      1       1   1015         290      1        314
# 152615  152615    1    0      1       1   1019         303      1        314
# 152616  152616    0    0      1       1   1019         303      1        314
# 156349  156349    1    0      1       1   1021         310      1        314
# 156350  156350    0    0      1       1   1021         310      1        314
#
#         converged
# 697             0
# 698             0
# 1131            0
# 1132            0
# 1493            0
# ...           ...
# 148966          0
# 152615          0
# 152616          0
# 156349          0
# 156350          0
#
# [184 rows x 10 columns]

# %%
grouped = df.groupby('q_desired')

dfs = [g for _, g in grouped]

f, ax = plt.subplots()

ax.plot(dfs[1]['time'], dfs[1]['q_measured'])


# for i, df in enumerate(dfs):
#     df = df.reset_index()
#     ax.plot(df.index.values, df['q_measured'])



# dfs[][['time', 'q_measured']].plot(x='time')

# %%
f, ax = plt.subplots()

ax.plot(df['time'], df['q_measured'])
ax.axhline(y=df['q_desired'].max(), linestyle=':', c='k')

ax.set(xlabel='Time [ps]')
# Out:
# [Text(0.5, 0, 'Time [ps]')]

# %%
plt.plot(df_r['i_ref'], df_r['q_measured'], 'o')
plt.plot(df_q['i_ref'], df_q['q_measured'], '--')

# %%
df_r
# Out:
#           time  clk  rst  start  enable  i_ref  q_measured  ready  q_desired  \
# 697        697    1    0      1       1    511          56      1         26
# 698        698    0    0      1       1    511          56      1         26
# 1131      1131    1    0      1       1    255          35      1         26
# 1132      1132    0    0      1       1    255          35      1         26
# 1493      1493    1    0      1       1    127          29      1         26
# ...        ...  ...  ...    ...     ...    ...         ...    ...        ...
# 148966  148966    0    0      1       1   1015         290      1        314
# 152615  152615    1    0      1       1   1019         303      1        314
# 152616  152616    0    0      1       1   1019         303      1        314
# 156349  156349    1    0      1       1   1021         310      1        314
# 156350  156350    0    0      1       1   1021         310      1        314
#
#         converged
# 697             0
# 698             0
# 1131            0
# 1132            0
# 1493            0
# ...           ...
# 148966          0
# 152615          0
# 152616          0
# 156349          0
# 156350          0
#
# [184 rows x 10 columns]

# %%
time = df.loc[:10, 'time']
clk = df.loc[:10, 'clk']

plt.step(time, clk)
