# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df   = pd.read_csv('q_fit_10bits_no_drop.txt', sep='\t', names=['Q'])
df_d = pd.read_csv('q_fit_10bits_with_drop.txt', sep='\t', names=['Q'])


plt.plot(df)
plt.step(df_d, '--')
df_d
# Out:
#        Q
# 0     22
# 1     22
# 2     21
# 3     21
# 4     21
# ...   ..
# 1018  23
# 1019  23
# 1020  23
# 1021  23
# 1022  23
#
# [1023 rows x 1 columns]
