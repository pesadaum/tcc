# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('./vars.txt', sep='\s+')
df = df.replace('x', 0).astype(int)

df_q = pd.read_csv('./q_fit_10bits_no_drop.txt', header=None)
df_q[1] = np.arange(0, 1023)
df_q.columns = ['q_measured', 'i_ref']

df_q = df_q.iloc[: , [1, 0]]

df_q
# Out:
#       i_ref  q_measured
# 0         0          22
# 1         1          22
# 2         2          22
# 3         3          22
# 4         4          22
# ...     ...         ...
# 1018   1018         300
# 1019   1019         303
# 1020   1020         307
# 1021   1021         310
# 1022   1022         314
#
# [1023 rows x 2 columns]

# %%
df_r = df[df['ready'] == 1]

# %%
f, ax = plt.subplots()

ax.plot(df['time'], df['q_measured'])
ax.axhline(y=df['q_desired'].max(), linestyle=':', c='k')

ax.set(xlabel='Time [ps]')
# Out:
# [Text(0.5, 0, 'Time [ps]')]

# %%
plt.plot(df_r['i_ref'], df_r['q_measured'], 'o')
plt.plot(df_q['i_ref'], df_q['q_measured'], '--')

# %%
df_r
# Out:
#      time  clk  rst  start  enable  i_ref  q_measured  ready  q_desired
# 85     85    1    0      1       1    511          50      1        147
# 86     86    0    0      1       1    511          50      1        147
# 207   207    1    0      1       1    767          90      1        147
# 208   208    0    0      1       1    767          90      1        147
# 401   401    1    0      1       1    895         150      1        147
# 402   402    0    0      1       1    895         150      1        147

# %%
time = df.loc[:10, 'time']
clk = df.loc[:10, 'clk']

plt.step(time, clk)
